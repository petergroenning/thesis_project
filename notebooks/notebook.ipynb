# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('../df.csv')

data.set_index('X',inplace=True)

df = data[1000:2000]


df
# Out:
#                                   X0         X1         X2         X3  \
# X
# 2017-03-14 16:00:00+01:00  10.250000  10.250000  10.300000  10.200000
# 2017-03-14 17:00:00+01:00  10.291667  10.250000  10.300000  10.200000
# 2017-03-14 18:00:00+01:00  10.316667  10.208333  10.300000  10.200000
# 2017-03-14 19:00:00+01:00  10.341667  10.208333  10.316667  10.208333
# 2017-03-14 20:00:00+01:00  10.316667  10.250000  10.308333  10.250000
# ...                              ...        ...        ...        ...
# 2017-04-25 03:00:00+01:00  15.950000  15.991667  16.000000  15.900000
# 2017-04-25 04:00:00+01:00  15.941667  15.950000  16.000000  15.900000
# 2017-04-25 05:00:00+01:00  15.900000  15.950000  15.991667  15.900000
# 2017-04-25 06:00:00+01:00  15.883333  15.916667  15.966667  15.900000
# 2017-04-25 07:00:00+01:00  15.858333  15.883333  15.950000  15.900000
#
#                                   X4         X5         X6         X7  \
# X
# ...

# %%
df = data[1:6000]



fig, ax = plt.subplots(3,1,figsize=(20, 10))
x = np.arange(0, 2000, 1)
df.X0.plot(ax=ax[0], color='blue')
df.X1.plot(ax=ax[0], color='green')
# df.X0.diff(1).plot(ax=ax[1], color='red')


# df.Fbot.plot(ax = ax[2])
# ax[1].plot(df.Fbot*(df.Tbot-df.X0)/1000,marker='o')

ax[1].plot(df.FbotOut*(df.X1-df.X0)/10)
ax[1].axhline(y=0, color='black', linestyle='--')

# %%
Y = df.FbotOut*(df.X1-df.X0)
Y = Y.values


plt.plot(Y[:2000]**2)

# %% [markdown]
# $$\frac{dX}{dt} = f(x) + \xi_t$$
